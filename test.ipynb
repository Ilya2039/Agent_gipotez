# %%
from langchain_community.chat_models.gigachat import GigaChat
import os

llm = GigaChat(
    credentials=os.environ["GIGACHAT_AUTH"],
    verify_ssl_certs=False,
    scope="GIGACHAT_API_CORP",
    model="GigaChat-2-Max",
    temperature=0.9,
    profanity_check=False
)

llm.invoke("Привет, как дела")
# Out:
# AIMessage(content='Привет! Всё отлично, настроение отличное — готов обсудить любую тему или решить интересную задачу. А ты как?', additional_kwargs={}, response_metadata={'token_usage': Usage(prompt_tokens=15, completion_tokens=24, total_tokens=39, precached_prompt_tokens=2), 'model_name': 'GigaChat-2-Max:2.0.28.2', 'finish_reason': 'stop'}, id='run-96af269a-694c-4462-b6e9-ffd1227dbaf6-0')

# %%
from langchain_community.chat_models.gigachat import GigaChat
import os

llm = GigaChat(
    credentials=os.environ["GIGACHAT_AUTH"],
    verify_ssl_certs=False,
    scope="GIGACHAT_API_CORP",
    model="GigaChat-2-Max",
    temperature=0.9,
    profanity_check=False
)

llm.invoke("Привет, как дела")
# Out:
# AIMessage(content='Привет! Всё отлично, настроение отличное — готов поговорить обо всём интересующем тебя. Чем займёмся?', additional_kwargs={}, response_metadata={'token_usage': Usage(prompt_tokens=15, completion_tokens=24, total_tokens=39, precached_prompt_tokens=2), 'model_name': 'GigaChat-2-Max:2.0.28.2', 'finish_reason': 'stop'}, id='run-cbdacf57-dad1-4f83-9373-623332532fba-0')
